# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
def arange(start,end,stride=1):
    return np.arange(start,end+0.00000001,stride)

# %%
# !pwd
# Out:
# /Users/earl/taxi/scripts

# %%
trip_fare_path = '/Users/earl/taxi/data/trip_fare_4.csv'
trip_data_path = '/Users/earl/taxi/data/trip_data_4.csv'

# %%
trip_fare = pd.read_csv(trip_fare_path)
trip_fare.columns
# Out:
# Index(['medallion', ' hack_license', ' vendor_id', ' pickup_datetime',
#        ' payment_type', ' fare_amount', ' surcharge', ' mta_tax',
#        ' tip_amount', ' tolls_amount', ' total_amount'],
#       dtype='object')

# %%
trip_fare
# Out:
#                                  medallion                      hack_license  \
# 0         91F6EB84975BBC867E32CB113C7C2CD5  AD8751110E6292079EB10EB9481FE1A6
# 1         EC34CD1B3797DFAFF3FE099BA87B6656  8FE6A4AEDF89B6B4E19D2377FD3FB7D7
# 2         C1B9DA774DC2BBC6DE27CE994E7F44A0  E1B595FD55E4C82C1E213EB17438107A
# 3         9BA84250355AB3FC031C9252D395BF8A  16BB0D96A0DCC853AEC7F55C8D6C71E0
# 4         205A696DF62AD03C88DA8C5EC5248639  579C41EA5EC846F8B641A42F9EE3E855
# 5         EE75E5927D00739AC342810C336A825E  1B4E92431F9DA4D49874EC76E769E874
# 6         3B5DA0DE0868F37FD41204DB36CE87CA  BC7B6E5A0132450CAE072F3C8F60BBE4
# 7         00B99071EE4DC8266384113B91E6AC13  013DB7F394A06CD241688F0F3E93F2F1
# 8         75FEF473DB69BA7BC5D61F5635792E1E  FCD2C03A60D84CE91A4DEB5E6A097FCF
# 9         13A57EE874E2560DF1F9D6C639BB7DAB  5FE3733438871FE98C05D259E8693750
# 10        7D712A934296BF961DBFF6A1C3FA6782  DEEF1A0383AF583019CF1E2628E00D12
# ...

# %%
trip_data = pd.read_csv(trip_data_path)
trip_data.columns
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['medallion', ' hack_license', ' vendor_id', ' rate_code',
#        ' store_and_fwd_flag', ' pickup_datetime', ' dropoff_datetime',
#        ' passenger_count', ' trip_time_in_secs', ' trip_distance',
#        ' pickup_longitude', ' pickup_latitude', ' dropoff_longitude',
#        ' dropoff_latitude'],
#       dtype='object')

# %%
trip_data
# Out:
#                                  medallion                      hack_license  \
# 0         91F6EB84975BBC867E32CB113C7C2CD5  AD8751110E6292079EB10EB9481FE1A6
# 1         EC34CD1B3797DFAFF3FE099BA87B6656  8FE6A4AEDF89B6B4E19D2377FD3FB7D7
# 2         C1B9DA774DC2BBC6DE27CE994E7F44A0  E1B595FD55E4C82C1E213EB17438107A
# 3         9BA84250355AB3FC031C9252D395BF8A  16BB0D96A0DCC853AEC7F55C8D6C71E0
# 4         205A696DF62AD03C88DA8C5EC5248639  579C41EA5EC846F8B641A42F9EE3E855
# 5         EE75E5927D00739AC342810C336A825E  1B4E92431F9DA4D49874EC76E769E874
# 6         3B5DA0DE0868F37FD41204DB36CE87CA  BC7B6E5A0132450CAE072F3C8F60BBE4
# 7         00B99071EE4DC8266384113B91E6AC13  013DB7F394A06CD241688F0F3E93F2F1
# 8         75FEF473DB69BA7BC5D61F5635792E1E  FCD2C03A60D84CE91A4DEB5E6A097FCF
# 9         13A57EE874E2560DF1F9D6C639BB7DAB  5FE3733438871FE98C05D259E8693750
# 10        7D712A934296BF961DBFF6A1C3FA6782  DEEF1A0383AF583019CF1E2628E00D12
# ...

# %%
# BQ a.
passco_raw = trip_data[[' passenger_count']]
passco_freq = passco_raw.groupby(' passenger_count')[' passenger_count'].count().to_frame(name='frequency')
passco_freq
# Out:
#                   frequency
#  passenger_count
# 0                       229
# 1                  10707072
# 2                   1985742
# 3                    609849
# 4                    298146
# 5                    890115
# 6                    609313
# 8                         1
# 9                         1

# %%
trip_fare_nzero = trip_fare[passco_raw[' passenger_count'] != 0]
trip_data_nzero = trip_data[passco_raw[' passenger_count'] != 0]

# %%
passco = trip_data_nzero[[' passenger_count']]
passco_freq = passco.groupby(' passenger_count')[' passenger_count'].count().to_frame(name='frequency')
passco_freq
# Out:
#                   frequency
#  passenger_count
# 1                  10707072
# 2                   1985742
# 3                    609849
# 4                    298146
# 5                    890115
# 6                    609313
# 8                         1
# 9                         1

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'

# %%
sns.countplot(x=' passenger_count', data=passco)

ax_pos = -0.05

plt.xlabel('Number of passenger', fontsize=15, fontweight='black', color = '#333F4B')

plt.ylabel('Trip count', fontsize=15, fontweight='black', color = '#333F4B', rotation='horizontal', ha='right')
plt.gca().yaxis.set_label_coords(ax_pos, 1.02)
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

plt.gca().tick_params(axis='both', which='major', labelsize=12)
plt.gca().spines['top'].set_color('none')
plt.gca().spines['right'].set_color('none')
plt.gca().spines['left'].set_smart_bounds(True)
plt.gca().spines['bottom'].set_smart_bounds(True)
plt.gca().spines['left'].set_position(('axes', ax_pos))
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# BQ b.
paytype = trip_fare_nzero[[' payment_type']]
paytype_freq = paytype.groupby(' payment_type')[' payment_type'].count().to_frame(name='frequency')
paytype_freq
# Out:
#                frequency
#  payment_type
# CRD              8105269
# CSH              6943646
# DIS                11551
# NOC                33591
# UNK                 6182

# %%
order = sorted(paytype[' payment_type'].value_counts().index)
sns.countplot(x=' payment_type', data=paytype, order=order)

ax_pos = -0.05

plt.xlabel('Payment type', fontsize=15, fontweight='black', color = '#333F4B')

plt.ylabel('Trip count', fontsize=15, fontweight='black', color = '#333F4B', rotation='horizontal', ha='right')
plt.gca().yaxis.set_label_coords(-0.05,1.02)
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

plt.gca().tick_params(axis='both', which='major', labelsize=12)
plt.gca().spines['top'].set_color('none')
plt.gca().spines['right'].set_color('none')
plt.gca().spines['left'].set_smart_bounds(True)
plt.gca().spines['bottom'].set_smart_bounds(True)
plt.gca().spines['left'].set_position(('axes', ax_pos))
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# BQ c.
fareamo = trip_fare_nzero[[' fare_amount']]
bins = arange(0,32)-0.5
fareamo['fare_amount_binned'] = pd.cut(fareamo[' fare_amount'], bins=bins, right=False)
fareamo_freq = fareamo.groupby('fare_amount_binned')['fare_amount_binned'].count().to_frame(name='frequency')
fareamo_freq
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                     frequency
# fare_amount_binned
# [-0.5, 0.5)                 0
# [0.5, 1.5)                  0
# [1.5, 2.5)                  0
# [2.5, 3.5)             113010
# [3.5, 4.5)             549972
# [4.5, 5.5)            1192518
# [5.5, 6.5)            1483460
# [6.5, 7.5)            1507361
# [7.5, 8.5)            1417640
# [8.5, 9.5)            1264739
# [9.5, 10.5)           1086809
# [10.5, 11.5)           914245
# [11.5, 12.5)           761871
# [12.5, 13.5)           631231
# [13.5, 14.5)           525148
# [14.5, 15.5)           439193
# [15.5, 16.5)           368644
# ...

# %%
sns.distplot(fareamo[' fare_amount'], hist=True, kde=False, bins=bins, hist_kws={'ec':"k"})

ax_pos = -0.05

bins_label = bins + 0.5
plt.xticks(bins_label[::2])
plt.xlim([bins_label[0], bins[-2]])
plt.xlabel('Fare amount ($)', fontsize=15, fontweight='black', color = '#333F4B')

plt.ylabel('Trip count', fontsize=15, fontweight='black', color = '#333F4B', rotation='horizontal', ha='right')
plt.gca().yaxis.set_label_coords(ax_pos,1.02)
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

plt.gca().tick_params(axis='both', which='major', labelsize=12)
plt.gca().spines['top'].set_color('none')
plt.gca().spines['right'].set_color('none')
plt.gca().spines['left'].set_smart_bounds(True)
plt.gca().spines['bottom'].set_smart_bounds(True)
plt.gca().spines['left'].set_position(('axes', ax_pos))
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# BQ d.
tipamo = trip_fare_nzero[[' tip_amount']]
bins = arange(0.5,16,0.5)-0.25
tipamo['tip_amount_binned'] = pd.cut(tipamo[' tip_amount'], bins)
tipamo_freq = tipamo.groupby('tip_amount_binned')['tip_amount_binned'].count().to_frame(name='frequency')
tipamo_freq
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                    frequency
# tip_amount_binned
# (0.25, 0.75]          117672
# (0.75, 1.25]         1848783
# (1.25, 1.75]         1417201
# (1.75, 2.25]         1541214
# (2.25, 2.75]          743609
# (2.75, 3.25]          603651
# (3.25, 3.75]          329685
# (3.75, 4.25]          265392
# (4.25, 4.75]          152646
# (4.75, 5.25]          187002
# (5.25, 5.75]           84999
# (5.75, 6.25]           90780
# (6.25, 6.75]           63586
# (6.75, 7.25]           63340
# (7.25, 7.75]           45120
# (7.75, 8.25]           49166
# (8.25, 8.75]           26766
# ...

# %%
sns.distplot(tipamo[' tip_amount'], hist=True, kde=False, bins=bins, hist_kws={'ec':"k"})

ax_pos = -0.05

bins_label = bins + 0.25
plt.xticks(bins_label[1::2])
plt.xlim([bins[0], bins[-2]])
plt.xlabel('Tip amount ($)', fontsize=15, fontweight='black', color = '#333F4B')

plt.ylabel('Trip count', fontsize=15, fontweight='black', color = '#333F4B', rotation='horizontal', ha='right')
plt.gca().yaxis.set_label_coords(ax_pos,1.02)
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

plt.gca().tick_params(axis='both', which='major', labelsize=12)
plt.gca().spines['top'].set_color('none')
plt.gca().spines['right'].set_color('none')
plt.gca().spines['left'].set_smart_bounds(True)
plt.gca().spines['bottom'].set_smart_bounds(True)
plt.gca().spines['left'].set_position(('axes', ax_pos))
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# BQ e.
totamo = trip_fare_nzero[[' total_amount']]
bins = arange(0,52,2)-1
totamo['tot_amount_binned'] = pd.cut(totamo[' total_amount'], bins)
totamo_freq = totamo.groupby('tot_amount_binned')['tot_amount_binned'].count().to_frame(name='frequency')
totamo_freq
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                    frequency
# tot_amount_binned
# (-1.0, 1.0]                0
# (1.0, 3.0]             23654
# (3.0, 5.0]            597157
# (5.0, 7.0]           2054823
# (7.0, 9.0]           2729850
# (9.0, 11.0]          2221008
# (11.0, 13.0]         1744384
# (13.0, 15.0]         1383322
# (15.0, 17.0]          895767
# (17.0, 19.0]          659835
# (19.0, 21.0]          528228
# (21.0, 23.0]          354882
# (23.0, 25.0]          273985
# (25.0, 27.0]          219376
# (27.0, 29.0]          149817
# (29.0, 31.0]          124920
# (31.0, 33.0]          111521
# ...

# %%
sns.distplot(totamo[' total_amount'], hist=True, kde=False, bins=bins, hist_kws={'ec':"k"})

ax_pos = -0.05

bins_label = bins + 1
plt.xticks(bins_label[0::2])
plt.xlim([bins_label[0], bins[-2]])
plt.xlabel('Total amount ($)', fontsize=15, fontweight='black', color = '#333F4B')

plt.ylabel('Trip count', fontsize=15, fontweight='black', color = '#333F4B', rotation='horizontal', ha='right')
plt.gca().yaxis.set_label_coords(ax_pos,1.02)
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

plt.gca().tick_params(axis='both', which='major', labelsize=12)
plt.gca().spines['top'].set_color('none')
plt.gca().spines['right'].set_color('none')
plt.gca().spines['left'].set_smart_bounds(True)
plt.gca().spines['bottom'].set_smart_bounds(True)
plt.gca().spines['left'].set_position(('axes', ax_pos))
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# BQ f.
putime = trip_fare_nzero[[' pickup_datetime']]
puhour = pd.DataFrame({'hour_24': [f[11:13] for f in putime[' pickup_datetime']]})
puhour_freq = puhour.groupby('hour_24')['hour_24'].count().to_frame(name='frequency')
puhour_freq

puhour_freq
# Out:
#          frequency
# hour_24
# 00          571017
# 01          412944
# 02          309328
# 03          223650
# 04          163398
# 05          143584
# 06          319627
# 07          581623
# 08          710682
# 09          725635
# 10          689782
# 11          704812
# 12          736467
# 13          723043
# 14          755500
# 15          720810
# 16          602772
# 17          739268
# 18          922172
# 19          950580
# 20          916988
# 21          881247
# 22          852388
# 23          742922

# %%
sns.countplot(x='hour_24', data=puhour)
plt.gcf().set_figwidth(plt.gcf().get_figwidth()*2)
ax_pos = -0.025

plt.xlabel('Pick up time (hour of the day)', fontsize=15, fontweight='black', color = '#333F4B')

plt.ylabel('Trip count', fontsize=15, fontweight='black', color = '#333F4B', rotation='horizontal', ha='right')
plt.gca().yaxis.set_label_coords(ax_pos, 1.02)
plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
plt.gca().get_yaxis().set_ticks(arange(0,800000,200000))

plt.gca().tick_params(axis='both', which='major', labelsize=12)
plt.gca().spines['top'].set_color('none')
plt.gca().spines['right'].set_color('none')
plt.gca().spines['left'].set_smart_bounds(True)
plt.gca().spines['bottom'].set_smart_bounds(True)
plt.gca().spines['left'].set_position(('axes', ax_pos))
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# BQ g.
pulon_raw = trip_data_nzero[[' pickup_longitude']]
pulat_raw = trip_data_nzero[[' pickup_latitude']]

pulon = pulon_raw\
[pulon_raw[' pickup_longitude'] < -73.925]\
[pulon_raw[' pickup_longitude'] > -74.025]\
[pulat_raw[' pickup_latitude'] > 40.7]\
[pulat_raw[' pickup_latitude'] < 40.825]

pulat = pulat_raw\
[pulon_raw[' pickup_longitude'] < -73.925]\
[pulon_raw[' pickup_longitude'] > -74.025]\
[pulat_raw[' pickup_latitude'] > 40.7]\
[pulat_raw[' pickup_latitude'] < 40.825]
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /Users/earl/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
sns.jointplot(x=pulon, y=pulat, kind="hex")

plt.gcf().set_figwidth(plt.gcf().get_figwidth()*2)
plt.gcf().set_figheight(plt.gcf().get_figheight()*2)

ax_pos = -0.05

# bins_label = bins + 1
# plt.xticks(bins_label[0::2])
# plt.xlim([bins_label[0], bins[-2]])
plt.xlabel('Total amount ($)', fontsize=15, fontweight='black', color = '#333F4B')

plt.ylabel('Trip count', fontsize=15, fontweight='black', color = '#333F4B', rotation='horizontal', ha='right')
plt.gca().yaxis.set_label_coords(-1,1.02)
# plt.gca().yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

# plt.gca().tick_params(axis='both', which='major', labelsize=12)
# plt.gca().spines['top'].set_color('none')
# plt.gca().spines['right'].set_color('none')
# plt.gca().spines['left'].set_smart_bounds(True)
# plt.gca().spines['bottom'].set_smart_bounds(True)
# plt.gca().spines['left'].set_position(('axes', ax_pos))
# Out:
# /Users/earl/miniconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# BQ h.
triptime = trip_data_nzero[[' trip_time_in_secs']]
# bins = arange(0,52,2)-1
# totamo['tot_amount_binned'] = pd.cut(totamo[' total_amount'], bins)
# totamo_freq = totamo.groupby('tot_amount_binned')['tot_amount_binned'].count().to_frame(name='frequency')
# totamo_freq

# %%
triptime
# Out:
#            trip_time_in_secs
# 0                        759
# 1                        540
# 2                       1318
# 3                        799
# 4                       1017
# 5                        189
# 6                        354
# 7                        452
# 8                        635
# 9                       1048
# 10                       439
# 11                      2415
# 12                      2769
# 13                       179
# 14                      1142
# 15                       720
# 16                       303
# 17                       433
# 18                       847
# 19                       528
# 20                      1197
# 21                      1384
# 22                       480
# 23                       843
# 24                       723
# 25                       731
# 26                       556
# 27                       456
# 28                       720
# 29                       377
# ...                      ...
# ...
